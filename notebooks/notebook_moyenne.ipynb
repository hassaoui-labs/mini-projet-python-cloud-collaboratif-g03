# %% [markdown]
# <a href="https://colab.research.google.com/github/hassaoui-labs/mini-projet-python-cloud-collaboratif-g03/blob/main/notebooks/notebook_moyenne.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Fonction moyenne**
# - Permet de calculer la moyenne d'une liste donnée en argument.
# - La fonction provoque une erreur ZeroDivisionError si la liste est vide

# %%
def moyenne(liste):
    if len(liste) == 0:
        raise ValueError("Liste vide : impossible de calculer la moyenne")
    return sum(liste) / len(liste)
print(moyenne([]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1338710588.py in <cell line: 0>()
#       3         raise ValueError("Liste vide : impossible de calculer la moyenne")
#       4     return sum(liste) / len(liste)
# ----> 5 print(moyenne([]))
#
# /tmp/ipython-input-1338710588.py in moyenne(liste)
#       1 def moyenne(liste):
#       2     if len(liste) == 0:
# ----> 3         raise ValueError("Liste vide : impossible de calculer la moyenne")
#       4     return sum(liste) / len(liste)
#       5 print(moyenne([]))
#
# ValueError: Liste vide : impossible de calculer la moyenne

# %% [markdown]
# **Version débogage**

# %%
def moyenne(liste):
    if len(liste) == 0:
        raise ValueError("Liste vide : impossible de calculer la moyenne")
    return sum(liste) / len(liste)

# %% [markdown]
# Tests contrôlés

# %%
print("moyenne([1,2,3]) =", moyenne([1,2,3]))

try:
    print("moyenne([]) =", moyenne([]))
except ValueError as e:
    print("Erreur attendue:", e)
# Out:
# moyenne([1,2,3]) = 2.0
# Erreur attendue: Liste vide : impossible de calculer la moyenne

# %% [markdown]
# Debugging

# %%
import pdb

def moyenne(liste):
    pdb.set_trace()  # point d’arrêt
    if len(liste) == 0:
        raise ValueError("Liste vide : impossible de calculer la moyenne")
    return sum(liste) / len(liste)

moyenne([1,2,3])
# Out:
# > /tmp/ipython-input-3931233437.py(5)moyenne()
#       3 def moyenne(liste):
#       4     pdb.set_trace()  # point d’arrêt
# ----> 5     if len(liste) == 0:
#       6         raise ValueError("Liste vide : impossible de calculer la moyenne")
#       7     return sum(liste) / len(liste)
#
# ipdb> p liste
# [1, 2, 3]
# ipdb> p len(liste)
# 3
# ipdb> n
# > /tmp/ipython-input-3931233437.py(7)moyenne()
#       5     if len(liste) == 0:
#       6         raise ValueError("Liste vide : impossible de calculer la moyenne")
# ----> 7     return sum(liste) / len(liste)
#       8
#       9 moyenne([1,2,3])
#
# ipdb> c
# 2.0
